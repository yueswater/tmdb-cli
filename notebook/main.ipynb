# %%
import os
import requests
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("TMDB_API_KEY")
lang = "en-US"
page = 1

url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwMDEyMWI4YTgxYTYwYTQyYjZhYmU1ZjNiMGEwNzBiNSIsIm5iZiI6MTc1NjczOTQ5NS42MjUsInN1YiI6IjY4YjViN2E3ZTRlMzNmMWE5ZTFmMjlhZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.83F8MZ9jpZIqdxLGbO6z8YBm3QyVonBf5KGSfLJODA0"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"dates":{"maximum":"2025-09-03","minimum":"2025-07-23"},"page":1,"results":[{"adult":false,"backdrop_path":"/iZLqwEwUViJdSkGVjePGhxYzbDb.jpg","genre_ids":[878,53],"id":755898,"original_language":"en","original_title":"War of the Worlds","overview":"Will Radford is a top analyst for Homeland Security who tracks potential threats through a mass surveillance program, until one day an attack by an unknown entity leads him to question whether the government is hiding something from him... and from the rest of the world.","popularity":1045.1683,"poster_path":"/yvirUYrva23IudARHn3mMGVxWqM.jpg","release_date":"2025-07-29","title":"War of the Worlds","video":false,"vote_average":4.323,"vote_count":466},{"adult":false,"backdrop_path":"/ZtcGMc204JsNqfjS9lU6udRgpo.jpg","genre_ids":[28,18],"id":911430,"original_language":"en","original_title":"F1","overview":"Racing legend Sonny Hayes is coaxed out of retirement to lead a struggling Formula 1 team—and mentor a young hotshot driver—while chasing 
# ...
